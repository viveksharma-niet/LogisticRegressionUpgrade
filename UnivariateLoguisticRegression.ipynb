# %% [markdown]
# <a href="https://colab.research.google.com/github/viveksharma-niet/LogisticRegressionUpgrade/blob/main/UnivariateLoguisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
diabetiesdata = pd.read_csv('https://raw.githubusercontent.com/viveksharma-niet/LogisticRegressionUpgrade/refs/heads/main/Diabetes%2BExample%2BData.csv', index_col= False)
diabetiesdata.head()
# Out:
#    Blood Sugar Level Diabetes
# 0                190       No
# 1                240      Yes
# 2                300      Yes
# 3                160       No
# 4                200      Yes
